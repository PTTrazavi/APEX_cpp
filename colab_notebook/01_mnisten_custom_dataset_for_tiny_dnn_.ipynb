# %% [markdown]
# ## Convert image files to idx format binaries

# %%
# !git clone https://github.com/nyanp/mnisten
# Out:
# Cloning into 'mnisten'...
# remote: Enumerating objects: 91, done.
# remote: Total 91 (delta 0), reused 0 (delta 0), pack-reused 91
# Unpacking objects: 100% (91/91), done.

# %%
# %cd mnisten/
# %pwd
# Out:
# /content/mnisten
# '/content/mnisten'

# %%
# !cp include/cmdline.h src/cmdline.h
# !cp include/util.h src/util.h

# %% [markdown]
# Edit makefile before execute the next block.
# /content/mnisten/makefile
# https://github.com/nyanp/mnisten/issues/6

# %%
# !make
# Out:
# g++ -Wall -O2   -std=c++0x -o mnisten src/main.cpp -lboost_system -lboost_filesystem -lopencv_calib3d  -lopencv_core -lopencv_features2d -lopencv_flann -lopencv_highgui -lopencv_imgproc  -lopencv_ml  -lopencv_objdetect -lopencv_photo -lopencv_stitching -lopencv_imgcodecs

# %%
# !unzip -qq 20211027_train.zip 
# !unzip -qq 20211027_test.zip

# !rm -r __MACOSX/
# !rm -r 20211027_train/.DS_Store
# !rm -r 20211027_test/.DS_Store

# %%
# !./mnisten -d 20211027_train -o apexTrain -s 28x28
# Out:
# 1:hyponea 90images
# 0:apnea 90images
# 2:normal 90images
# total 270images found.

# %%
# !./mnisten -d 20211027_test -o apexTest -s 28x28
# Out:
# 1:hyponea 10images
# 0:apnea 10images
# 2:normal 10images
# total 30images found.

# %% [markdown]
# https://github.com/nyanp/mnisten
